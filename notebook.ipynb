# %%
import random
from datetime import datetime
import time
import polars as pl
import duckdb

# replace pl.scan_parquet with read_parquet
#df = pl.read_parquet("/Users/dnagaraj/Downloads/part-00075-b93ce855-6d77-4f21-b9a1-1dfcbf4f6cbc.c000.snappy.parquet")
df = pl.read_parquet("/home/workspace/notebooks_test/notebooks_test/test.snappy.parquet")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 from datetime import datetime
#       3 import time
# ----> 4 import polars as pl
#       5 import duckdb
#       7 # replace pl.scan_parquet with read_parquet
#       8 #df = pl.read_parquet("/Users/dnagaraj/Downloads/part-00075-b93ce855-6d77-4f21-b9a1-1dfcbf4f6cbc.c000.snappy.parquet")
#
# ModuleNotFoundError: No module named 'polars'

# %%
#df.schema
duckdb.sql('SELECT * FROM df limit 10').show()
#duckdb.sql('SELECT count(*) FROM df limit 10').show()

# %%
#duckdb.sql('SELECT count(*) FROM df limit 10').show()

# %%
#4th

# %%
#5th

# %%
#6th 2023-08-21

# %%
#7 2023-08-24 
# test for checkpoint
# check point test 2

# %%
#7 2023-08-25
#checkpoint 1
